# %%
import pandas as pd
from tools.news_scraping import * # import all functions from news_scraping.py

# %%
stock_names = [
    "ASTOR",
    "ENJSA",
    "TCELL",
    "TTKOM",
    "OYAKC",
    "KONYA",
    "YBTAS",
    "EREGL",
    "KRDMD",
    "TOASO",
    "FROTO",
    "BIMAS",
    "SOKM",
    "ARCLK",
    "VESTL",
    "THYAO",
    "PGSUS"
] # list of stock names

# %%
news = pd.read_csv("news.csv") # read news.csv file

# %%
stock_prices = pd.read_csv("stock_market_prices_all.csv") # read stock_market_prices_all.csv file

# %%
dates = stock_prices["Date"].unique() # get unique dates from stock_prices dataframe

# %% [markdown]
# ## Adding Labels as List and Converting Date as Appropriate Form

# %%
for i in dates:
    df_d = pd.read_csv(f"daily_changes/{i}.csv")
    df_d["text"] = df_d["Stock_Code"] + " : " + df_d["Change_Status"].astype(str)
    text = list(df_d["text"].values)
    text = str(text)
    dt = convdate2datetime(i)
    for j in news["date"].values:
        if dt == convlist2datetime(j.split(",")[0].split(" ")[:3]):
            news.loc[news["date"] == j, "label"] = text

# %%
news["date"] = news["date"].apply(lambda x: convlist2datetime(x.split(' '))) # convert date column to datetime format

# %% [markdown]
# ## Splitting List for All Stock Codes

# %%
labels = news["label"].str.split(",", expand=True) # split label column by comma 
labels.columns = stock_names # set column names as stock names

labels["PGSUS"] = labels["PGSUS"].str[-4:-2].str.replace(" ", "").astype(int) + 1 # convert PGSUS column to integer 

stock_names2 = [
    "ASTOR",
    "ENJSA",
    "TCELL",
    "TTKOM",
    "OYAKC",
    "KONYA",
    "YBTAS",
    "EREGL",
    "KRDMD",
    "TOASO",
    "FROTO",
    "BIMAS",
    "SOKM",
    "ARCLK",
    "VESTL",
    "THYAO"
]

for column in stock_names2:
    labels[column] = labels[column].str[-3:-1].str.replace(" ", "").astype(int) + 1     # convert other columns to integer

# %%
data = pd.concat([news, labels], axis=1) # concatenate news and labels dataframes 
data = data.drop("label", axis=1) # drop label column

# %%
data
# Out:
#                                                  title  \
# 0                      Reeskont faizlerinde değişiklik
# 1    Doğalgazda Eylül tarifesinde değişikliğe gidil...
# 2           Ekonomi ve siyaset gündemi -  1 Eylül 2023
# 3     Asya borsaları Çin'den gelen haberlerle yükseldi
# 4     Çin Merkez Bankası'ndan zorunlu karşılık hamlesi
# ..                                                 ...
# 791  ABD’de Cumhuriyetçilerin bütçe tasarısı Temsil...
# 792                             S&P’den Türkiye kararı
# 793                             7 başlıkla geçen hafta
# 794           Mevduat faizi ticari kredi faizini geçti
# 795      Çin'de resmi imalat göstergesi pozitife döndü
#
#                                                   link  \
# 0             /reeskont-faizlerinde-degisiklik-2337536
# 1    /dogalgazda-eylul-tarifesinde-degisiklige-gidi...
# 2     /ekonomi-ve-siyaset-gundemi-1-eylul-2023-2337538
# 3    /asya-borsalari-cin-den-gelen-haberlerle-yukse...
# 4    /cin-merkez-bankasi-ndan-zorunlu-karsilik-haml...
# ..                                                 ...
# 791  /abdde-cumhuriyetcilerin-gecici-butce-tasarisi...
# 792                     /s-pden-turkiye-karari-2339324
# 793                    /7-baslikla-gecen-hafta-2339326
# 794  /mevduat-faizi-ticari-kredi-faizini-gecti-2339327
# 795  /cin-de-resmi-imalat-gostergesi-pozitife-dondu...
#
#                                                   text       date  ASTOR  \
# 0    Türkiye Cumhuriyet Merkez Bankası reeskont işl... 2023-09-01      0
# 1    BOTAŞ'ın internet sitesinde yayımlanan tarife ... 2023-09-01      0
# 2    1- Yeni adli yıl başlıyor - Yargıtay Başkanı M... 2023-09-01      0
# 3    Asya-Pasifik piyasaları, Çin'in ağustos ayında... 2023-09-01      0
# 4    Dünyanın en büyük ikinci ekonomisinde sorunlu ... 2023-09-01      0
# ..                                                 ...        ...    ...
# 791  Temsilciler Meclisi Başkanı Cumhuriyetçi McCar... 2023-09-29      1
# 792  Fitch’in ardından S&P de Türkiye’nin not görün... 2023-09-29      1
# 793  Küresel piyasaların ABD'den gelen gelişmeler d... 2023-09-30      1
# 794  Mevduat faizlerinde tarihi yüksek seviyeler ka... 2023-09-30      1
# 795  Çin'in imalat faaliyetleri altı ay sonra ilk k... 2023-09-30      1
#
#      ENJSA  TCELL  TTKOM  OYAKC  KONYA  ...  EREGL  KRDMD  TOASO  FROTO  \
# 0        2      2      2      0      2  ...      2      2      2      2
# 1        2      2      2      0      2  ...      2      2      2      2
# 2        2      2      2      0      2  ...      2      2      2      2
# 3        2      2      2      0      2  ...      2      2      2      2
# 4        2      2      2      0      2  ...      2      2      2      2
# ..     ...    ...    ...    ...    ...  ...    ...    ...    ...    ...
# 791      1      2      2      2      2  ...      1      1      2      2
# 792      1      2      2      2      2  ...      1      1      2      2
# 793      1      2      2      2      2  ...      1      1      2      2
# 794      1      2      2      2      2  ...      1      1      2      2
# 795      1      2      2      2      2  ...      1      1      2      2
#
#      BIMAS  SOKM  ARCLK  VESTL  THYAO  PGSUS
# 0        2     1      1      0      2      2
# 1        2     1      1      0      2      2
# 2        2     1      1      0      2      2
# 3        2     1      1      0      2      2
# 4        2     1      1      0      2      2
# ..     ...   ...    ...    ...    ...    ...
# 791      2     0      2      2      1      1
# 792      2     0      2      2      1      1
# 793      2     0      2      2      1      1
# 794      2     0      2      2      1      1
# 795      2     0      2      2      1      1
#
# [796 rows x 21 columns]

# %% [markdown]
# ## Translating Texts with Google API

# %%
from googletrans import Translator 
import googletrans

googletrans.__version__
# Out:
# 4.0.0-rc.1

# %%
translator = Translator(service_urls=[
      'translate.google.com',
      'translate.google.co.kr',
    ]) # create translator object

# %%
def translate_text(x): # translate text to english
    try:
        return translator.translate(x, dest="en").text
    except:
        return None

# %%
data["text_en"] = data["text"].apply(translate_text) # apply translate_text function to text column

# %%
data.to_csv("news_labels_en.csv") # save dataframe as csv file
